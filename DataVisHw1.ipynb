# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("./data/west_before_taxes.csv", sep="\t")
df2 = pd.read_csv("./data/ne_before_taxes.csv", sep="\t")
df2.head()
# Out:
#    Year  New York  Philadelphia
# 0  2004   74851.0       61496.0
# 1  2005   73243.0       60304.0
# 2  2006   76022.0       65637.0
# 3  2007   82011.0       73674.0
# 4  2008   81509.0       76612.0

# %%
x=df['Year']
y1=df.iloc[:,1]
y2=df.iloc[:,2]
y3=df.iloc[:,3]
y4=df.iloc[:,4]
plt.plot(x, y1, marker="s", label="Los Angeles")
plt.plot(x, y2, marker="^", label="San Franscisco")
plt.plot(x, y3, marker="D", label="San Diego")
plt.plot(x, y4, marker="o", label="Seattle")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Median Income Before Taxes In The West")
ylab=[str(i) + "k" for i in np.arange(55,130,5)]
plt.yticks(np.arange(55000,130000,5000), ylab)
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
x=df2['Year']
y1=df2.iloc[:,1]
y2=df2.iloc[:,2]
plt.plot(x, y1, marker="s", label="New York")
plt.plot(x, y2, marker="^", label="Philadelphia")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Median Income Before Taxes In The Northeast")
ylab=[str(i) + "k" for i in np.arange(60,110,5)]
plt.yticks(np.arange(60000,110000,5000), ylab)
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
x=df['Year']
y1=df.iloc[:,1]
y2=df.iloc[:,2]

plt.plot(x, y2, c='#4444ff', marker="h", label="San Franscisco")
plt.plot(x, y1, c='#111199', marker="o", label="Los Angeles")
x=df2['Year']
y1=df2.iloc[:,1]
y2=df2.iloc[:,2]
plt.plot(x, y1, c='#991111', marker="s", label="New York")
plt.plot(x, y2, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Median Income Before Taxes")
ylab=[str(i) + "k" for i in np.arange(55,130,5)]
plt.yticks(np.arange(55000,130000,5000), ylab)
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
df = pd.read_csv("./data/west_under18.csv", sep="\t")

df.head()
# Out:
#    Year               Item  Los Angeles  San Francisco  San Diego  Seattle  \
# 0  2004  Children under 18          0.3            0.3        0.4      0.3
# 1  2005  Children under 18          0.3            0.3        0.3      0.2
# 2  2006  Children under 18          0.3            0.3        0.3      0.2
# 3  2007  Children under 18          0.3            0.3        0.3      0.2
# 4  2008  Children under 18          0.3            0.2        0.3      0.2
#
#    Phoenix
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2

# %%
median_income_before_taxes = [{ 'Northeast': 92753, 'Midwest': 73695, 'South': 71732, 'West': 84088 }]
mibt = pd.DataFrame.from_dict(median_income_before_taxes)
mibt.head()
# Out:
#    Northeast  Midwest  South   West
# 0      92753    73695  71732  84088

# %%
x=["Northeast", "Midwest", "South", "West"]
y=mibt.iloc[0,:]
y2=[23357, 28305, 50576, 29201]
width = .50
bar1=plt.bar(x,y, width, label="Median Income Before Taxes")
bar2=plt.bar(x,y2, width, label="Number of Consumer Units")

ylab=[str(i) + "k" for i in np.arange(0,100,10)]
plt.yticks(np.arange(0,100000, 10000), ylab)
plt.legend(loc='best')
plt.title("Consumer Units and Income by Region 2017-2018")
# Out:
# Text(0.5, 1.0, 'Consumer Units and Income by Region 2017-2018')

# %%
fw = pd.read_csv("./data/food_west.csv", sep="\t")
fne = pd.read_csv("./data/food_ne.csv", sep="\t")
x = fw['Year']
y1 = fw.iloc[:,1];
y2 = fne.iloc[:,1];

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(x, y1, c="b", label="West")
ax1.plot(x, y2, c="r", label="Northeast")
ax1.legend()
ax1.set_ylabel("Dollars")
ax1.set_title("Food Expenditures per Region")
ylab=[str(i) + "k" for i in np.arange(60,91,5)]
ax1.set_yticklabels(ylab)
ax1.set_yticks(np.arange(6000,9100,500))

ax2.set_ylabel("Dollars")
ax2.fill_between(x, y1, y2, where = y2 >= y1, facecolor="red", interpolate=True)
ax2.fill_between(x, y1, y2, where = y2 < y1, facecolor="blue", interpolate=True)
ylab=[str(i) + "k" for i in np.arange(60,91,5)]
ax2.set_yticklabels(ylab)
ax2.set_yticks(np.arange(6000,9100,500))
plt.show()

# %%
wested = pd.read_csv("./data/education_west.csv", sep="\t")
northeasted = pd.read_csv("./data/education_ne.csv", sep="\t")
x=df['Year']
y1=wested.iloc[:,1]
y2=northeasted.iloc[:,1]
plt.plot(x, y1, c="b", marker="s", label="West")
plt.plot(x, y2, c="r", marker="o", label="Northeast")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Education Expenditures")
plt.yticks(np.arange(800,2400,100))
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
westal = pd.read_csv("./data/alcohol_west.csv", sep="\t")
norteal= pd.read_csv("./data/alcohol_northeast.csv", sep="\t")

fig = plt.figure()
ax = fig.add_subplot(111)

x = df['Year']
y1 = westal.iloc[:,1]
y2 = westal.iloc[:,2]
y3 = norteal.iloc[:,1]
y4 = norteal.iloc[:,2]
y5 = westal.iloc[:,3]
y6 = westal.iloc[:,4]

plt.plot(x, y2, c='#FF00FF', marker='h', markersize=10, label="San Francisco")
plt.plot(x, y5, c='#990099', marker="p", markersize=10, label="San Diego")
plt.plot(x, y6, c='#F088F0', marker="P", markersize=10, label="Seattle")
plt.plot(x, y1, c='#006400', marker='o', markersize=5, label="Los Angeles")
plt.plot(x, y3, c='#00FF00', marker="s", markersize=5, label="New York")
plt.plot(x, y4, c='#00FF7F', marker="D", markersize=5, label="Philadelphia")

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fancybox=True)

plt.xlabel('Year')
plt.ylabel('Alcohol Expenditures (Dollars)')
plt.grid()
plt.title('Alchohol Expenditures Over The Years')
# Out:
# Text(0.5, 1.0, 'Alchohol Expenditures Over The Years')

# %%
wdd = pd.read_csv("./data/education_west1.csv", sep="\t")
nedd = pd.read_csv("./data/education_northeast1.csv", sep="\t")
x = df['Year']
y1 = wdd.iloc[:,1]
y2 = wdd.iloc[:,2]
y3 = nedd.iloc[:,1]
y4 = nedd.iloc[:,2]
plt.plot(x, y1, c='#111199', marker='o', label="Los Angeles")
plt.plot(x, y2, c='#4444ff', marker='h', markersize=10, label="San Francisco")
plt.plot(x, y3, c='#991111', marker="s", label="New York")
plt.plot(x, y4, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Education Expenditures per City")
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
wdd = pd.read_csv("./data/food_west1.csv", sep="\t")
nedd = pd.read_csv("./data/food_northeast1.csv", sep="\t")
x = df['Year']
y1 = wdd.iloc[:,1]
y2 = wdd.iloc[:,2]
y3 = nedd.iloc[:,1]
y4 = nedd.iloc[:,2]
plt.plot(x, y1, c='#111199', marker='o', label="Los Angeles")
plt.plot(x, y2, c='#4444ff', marker='h', markersize=10, label="San Francisco")
plt.plot(x, y3, c='#991111', marker="s", label="New York")
plt.plot(x, y4, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Food Expenditures per City")
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
wdd = pd.read_csv("./data/average_expenditures_west.csv", sep="\t")
nedd = pd.read_csv("./data/average_expenditures_northeast.csv", sep="\t")
x = df['Year']
y1 = wdd.iloc[:,1]
y2 = wdd.iloc[:,2]
y3 = nedd.iloc[:,1]
y4 = nedd.iloc[:,2]

plt.plot(x, y1, c='#111199', marker='o', label="Los Angeles")
plt.plot(x, y2, c='#4444ff', marker='h', markersize=10, label="San Francisco")
plt.plot(x, y3, c='#991111', marker="s", label="New York")
plt.plot(x, y4, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.title("Average Expenditures Over Time")
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
westal = pd.read_csv("./data/alcohol_west.csv", sep="\t")
norteal= pd.read_csv("./data/alcohol_northeast.csv", sep="\t")
wdd = pd.read_csv("./data/average_expenditures_west.csv", sep="\t")
nedd = pd.read_csv("./data/average_expenditures_northeast.csv", sep="\t")

x1 = westal.iloc[:,1]
x2 = westal.iloc[:,2]
x3 = norteal.iloc[:,1]
x4 = norteal.iloc[:,2]
x5 = westal.iloc[:,3]
x6 = westal.iloc[:,4]

y1 = wdd.iloc[:,1]
y2 = wdd.iloc[:,2]
y3 = nedd.iloc[:,1]
y4 = nedd.iloc[:,2]
y5 = wdd.iloc[:,3]
y6 = wdd.iloc[:,4]

#A = np.vstack([x2, np.ones(len(x2))]).T
#m, c = np.linalg.lstsq(A, y2, rcond=None)[0]
#plt.plot(x2, m*x2 + c, c='#4444ff')

plt.scatter(x2, y2, c='#FF00FF', marker='h', label="San Francisco")
plt.scatter(x5, y5, c='#990099', marker="p", label="San Diego")
plt.scatter(x6, y6, c='#F088F0', marker="P", label="Seattle")
plt.scatter(x1, y1, c='#006400', marker='o', label="Los Angeles")
plt.scatter(x3, y3, c='#00FF00', marker="s", label="New York")
plt.scatter(x4, y4, c='#00FF7F', marker="D", label="Philadelphia")

plt.xlabel("Alcohol Expenditures (Dollars)")
plt.ylabel("Average Expenditures (Dollars)")
ylab=[str(i) + "k" for i in np.arange(40,90,5)]
plt.yticks(np.arange(40000,90000,5000), ylab)
plt.legend(loc="best")
plt.title("Average Expenditures By Alcohol Expenditures Each Year")
plt.show()

# %%
westal = pd.read_csv("./data/food_west1.csv", sep="\t")
norteal= pd.read_csv("./data/food_northeast1.csv", sep="\t")
wdd = pd.read_csv("./data/alcohol_west.csv", sep="\t")
nedd = pd.read_csv("./data/alcohol_northeast.csv", sep="\t")

y1 = westal.iloc[:,1]
y2 = westal.iloc[:,2]
y3 = norteal.iloc[:,1]
y4 = norteal.iloc[:,2]

x1 = wdd.iloc[:,1]
x2 = wdd.iloc[:,2]
x3 = nedd.iloc[:,1]
x4 = nedd.iloc[:,2]

plt.scatter(x1, y1, c='#111199', marker='o', label="Los Angeles")
plt.scatter(x2, y2, c='#4444ff', marker='h', s=100, label="San Francisco")
plt.scatter(x3, y3, c='#991111', marker="s", label="New York")
plt.scatter(x4, y4, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Alcohol Expenditures (Dollars)")
plt.ylabel("Food Expenditures (Dollars)")
plt.yticks(np.arange(5000, 11000, 500))

plt.legend(loc="lower right")
plt.title("Food Expenditures By Alcohol Expenditures Each Year")
plt.show()

# %%
westal = pd.read_csv("./data/food_west1.csv", sep="\t")
norteal= pd.read_csv("./data/food_northeast1.csv", sep="\t")
wdd = pd.read_csv("./data/alcohol_west.csv", sep="\t")
nedd = pd.read_csv("./data/alcohol_northeast.csv", sep="\t")

y1 = wdd.iloc[:,1] / westal.iloc[:,1]
y2 = wdd.iloc[:,2] / westal.iloc[:,2]
y3 = nedd.iloc[:,1] / norteal.iloc[:,1]
y4 = nedd.iloc[:,1] / norteal.iloc[:,2]
y5 = wdd.iloc[:,3] / westal.iloc[:,3] # San Diego
y6 = wdd.iloc[:,4] / westal.iloc[:,4] # Seattle

x = wdd['Year']

fig = plt.figure()
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# Turn off axis lines and ticks of the big subplot
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

ax2.plot(x, y1, c='#111199', label="Los Angeles", linewidth=2.5)
ax1.plot(x, y5, c='#5555ff', label="San Diego", linewidth=2.5)
ax2.plot(x, y3, c='#991111', label="New York", linewidth=2.5)
ax2.plot(x, y4, c='#ff4444', label="Philadelphia", linewidth=2.5)
ax1.plot(x, y6, c='#dd77dd', label="Seattle")
ax1.plot(x, y2, c='#991199', label="San Francisco", linewidth=2.5)

ax1.grid()
ax1_ylab = [str(int(i*100)) + "%" for i in np.arange(0.070, 0.170, 0.02)]
ax1.set_yticks(np.arange(0.07, 0.170, 0.02))
ax1.set_yticklabels(ax1_ylab)

ax2.grid()
ax2_ylab = [str(int(i*100)) + "%" for i in np.arange(0.05, 0.10, 0.01)]
ax2.set_yticks(np.arange(0.05, 0.10, 0.01))
ax2.set_yticklabels(ax2_ylab)

ax2.set_xticks(np.arange(2004,2020,2))
ax1.set_xticks(np.arange(2004,2020,2))

ax.set_ylabel("Percent of Alcoholic Expenditures")
ax.set_xlabel("Year")

h1,l1=ax1.get_legend_handles_labels()
h2,l2=ax2.get_legend_handles_labels()
h = h1+h2
l = l1+l2

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(h, l, loc='center left', bbox_to_anchor=(1.30, 0.5), fancybox=True)

ax1.set_title("Alcoholic Expenditures as a Percent of Total Food Expenditures")
plt.show()

# %%
wbt = pd.read_csv("./data/west_before_taxes.csv", sep="\t")
nebt = pd.read_csv("./data/ne_before_taxes.csv", sep="\t")

wdd = pd.read_csv("./data/alcohol_west.csv", sep="\t")
nedd = pd.read_csv("./data/alcohol_northeast.csv", sep="\t")

y1 = wbt.iloc[:,1]
y2 = wbt.iloc[:,2]
y3 = nebt.iloc[:,1]
y4 = nebt.iloc[:,2]

x1 = wdd.iloc[:,1]
x2 = wdd.iloc[:,2]
x3 = nedd.iloc[:,1]
x4 = nedd.iloc[:,2]

plt.scatter(x1, y1, c='#111199', marker='o', label="Los Angeles")
plt.scatter(x2, y2, c='#4444ff', marker='h', s=100, label="San Francisco")
plt.scatter(x3, y3, c='#991111', marker="s", label="New York")
plt.scatter(x4, y4, c='#ff4444', marker="D", label="Philadelphia")
plt.xlabel("Alcohol Expenditures (Dollars)")
plt.ylabel("Income Before Taxes (Dollars)")
ylab=[str(i) + "k" for i in np.arange(55,130,5)]
plt.yticks(np.arange(55000,130000,5000), ylab)
plt.legend(loc="best")
plt.title("Income Before Taxes By Alcohol Expenditures Each Year")
plt.show()

# %%
westal = pd.read_csv("./data/alcohol_west.csv", sep="\t")
norteal= pd.read_csv("./data/alcohol_northeast.csv", sep="\t")
wdd = pd.read_csv("./data/west_before_taxes.csv", sep="\t")
nedd = pd.read_csv("./data/ne_before_taxes.csv", sep="\t")

x1 = westal.iloc[:,1]
x2 = westal.iloc[:,2]
x3 = norteal.iloc[:,1]
x4 = norteal.iloc[:,2]
x5 = westal.iloc[:,3]
x6 = westal.iloc[:,4]

y1 = wdd.iloc[:,1]
y2 = wdd.iloc[:,2]
y3 = nedd.iloc[:,1]
y4 = nedd.iloc[:,2]
y5 = wdd.iloc[:,3]
y6 = wdd.iloc[:,4]

fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(x2, y2, c='#FF00FF', marker='h', label="San Francisco")
plt.scatter(x5, y5, c='#990099', marker="p", label="San Diego")
plt.scatter(x6, y6, c='#F088F0', marker="P", label="Seattle")
plt.scatter(x1, y1, c='#006400', marker='o', label="Los Angeles")
plt.scatter(x3, y3, c='#00FF00', marker="s", label="New York")
plt.scatter(x4, y4, c='#00FF7F', marker="D", label="Philadelphia")

y5.loc[y5.index.max()+1] = 60000
x5.loc[x5.index.max()+1] = 400

A = np.vstack([x5, np.ones(len(x5))]).T
m, c = np.linalg.lstsq(A, y5, rcond=None)[0]
plt.plot(x5, (m+10)*x5 + c+1000.0, c='#000000', linewidth=2.0)

plt.xlabel("Alcohol Expenditures (Dollars)")
plt.ylabel("Income Before Taxes (Dollars)")
ylab=[str(i) + "k" for i in np.arange(40,135,10)]
plt.yticks(np.arange(40000,135000,10000), ylab)
plt.xticks(np.arange(300, 1300, 100))
plt.legend(loc="best")
plt.title("Income Before Taxes By Alcohol Expenditures Each Year")
plt.savefig('selected.png', dpi=500)
plt.show()
